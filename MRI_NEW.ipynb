# %%
import pandas as pd
import numpy as np

# %%
file_path = \breast+cancer+wisconsin+diagnostic\\wdbc.data"  
df = pd.read_csv(file_path, header=None)  


csv_file_path = 'mri_file.csv'  
df.to_csv(csv_file_path, index=False, header=False)

# %%
import pandas as pd


columns = [
    "ID",  # ID number
    "Diagnosis",  # Diagnosis (M = malignant, B = benign)
    "radius_mean",  # Mean of distances from center to points on the perimeter
    "texture_mean",  # Standard deviation of gray-scale values
    "perimeter_mean",  # Perimeter
    "area_mean",  # Area
    "smoothness_mean",  # Local variation in radius lengths
    "compactness_mean",  # Perimeter² / area - 1.0
    "concavity_mean",  # Severity of concave portions of the contour
    "concave_points_mean",  # Number of concave portions of the contour
    "symmetry_mean",  # Symmetry
    "fractal_dimension_mean",  # Fractal dimension (coastline approximation - 1)
    "radius_se",  # Standard error of radius
    "texture_se",  # Standard error of texture
    "perimeter_se",  # Standard error of perimeter
    "area_se",  # Standard error of area
    "smoothness_se",  # Standard error of smoothness
    "compactness_se",  # Standard error of compactness
    "concavity_se",  # Standard error of concavity
    "concave_points_se",  # Standard error of concave points
    "symmetry_se",  # Standard error of symmetry
    "fractal_dimension_se",  # Standard error of fractal dimension
    "radius_worst",  # Worst (largest) radius
    "texture_worst",  # Worst (largest) texture
    "perimeter_worst",  # Worst (largest) perimeter
    "area_worst",  # Worst (largest) area
    "smoothness_worst",  # Worst (largest) smoothness
    "compactness_worst",  # Worst (largest) compactness
    "concavity_worst",  # Worst (largest) concavity
    "concave_points_worst",  # Worst (largest) concave points
    "symmetry_worst",  # Worst (largest) symmetry
    "fractal_dimension_worst"  # Worst (largest) fractal dimension
]


csv_file_path = 'mri_file.csv'  


df = pd.read_csv(csv_file_path, header=None) 
df.columns = columns  


print(df.head())


df.to_csv('output_with_headers.csv', index=False)
# Out:
#          ID Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df=pd.read_csv("output_with_headers.csv")
df.head()
# Out:
#          ID Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.isnull().sum()
# Out:
# ID                         0
# Diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave_points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt



sns.set(style="whitegrid")


pairplot = sns.pairplot(df[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'Diagnosis']], hue='Diagnosis')
pairplot.fig.suptitle("Pairplot of Key Features", y=1.02)
pairplot.savefig("pairplot_key_features.png")
plt.close()


plt.figure(figsize=(8, 6))
sns.boxplot(x='Diagnosis', y='radius_mean', data=df)
plt.title('Boxplot of Radius Mean by Diagnosis')
plt.savefig("boxplot_radius_mean.png")
plt.close()


plt.figure(figsize=(10, 8))
corr = df.drop(columns=['ID', 'Diagnosis']).corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title('Correlation Heatmap')
plt.savefig("correlation_heatmap.png")
plt.close()


plt.figure(figsize=(8, 6))
sns.violinplot(x='Diagnosis', y='area_mean', data=df)
plt.title('Violin Plot of Area Mean by Diagnosis')
plt.savefig("violin_plot_area_mean.png")
plt.close()


plt.figure(figsize=(8, 6))
sns.scatterplot(x='smoothness_mean', y='compactness_mean', hue='Diagnosis', data=df, palette='Set1')
plt.title('Smoothness Mean vs Compactness Mean')
plt.savefig("scatter_smoothness_vs_compactness.png")
plt.close()


plt.figure(figsize=(8, 6))
sns.histplot(df['perimeter_mean'], kde=True, bins=20, color='skyblue')
plt.title('Distribution of Perimeter Mean')
plt.savefig("distribution_perimeter_mean.png")
plt.close()

# %%
df=df.drop(['ID'],axis=1)
df.shape
# Out:
# (569, 31)

# %%
df['Diagnosis'] = df['Diagnosis'].map({'M': 1, 'B': 0})
df.head()
# Out:
#    Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df['Diagnosis'].value_counts()
# Out:
# Diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
from scipy.stats import boxcox
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split



X = df.drop(columns=['Diagnosis']) 
y = df['Diagnosis']


for col in X.columns:
    if X[col].min() > 0:  
        X[col], _ = boxcox(X[col])


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
X_train[0]
# Out:
# array([-1.90276109, -0.37752812, -1.78406175, -1.8661846 ,  0.76310853,
#         0.85590578,  2.81483311, -0.13333286,  1.10469102,  1.99518728,
#         0.00965823,  0.17453576, -0.40318459, -0.67219937,  1.02961482,
#         2.19824628,  9.01560288,  3.47515764,  1.96575311,  1.86006907,
#        -1.69251952, -0.42324101, -1.73825894, -1.67464169,  0.73038032,
#         1.19157717,  4.7006688 ,  0.91959172,  1.87727464,  1.65325592])

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier


svm = SVC(kernel='rbf', probability=True)  
knn = KNeighborsClassifier(n_neighbors=5)  


svm.fit(X_train, y_train)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.ensemble import VotingClassifier


ensemble_model = VotingClassifier(estimators=[
    ('svm', svm),
    ('knn', knn)
], voting='soft')

ensemble_model.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('svm', SVC(probability=True)),
#                              ('knn', KNeighborsClassifier())],
#                  voting='soft')

# %%
from sklearn.metrics import accuracy_score, classification_report


y_pred = ensemble_model.predict(X_test)


print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9649122807017544
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        71
#            1       0.95      0.95      0.95        43
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114

# %%
import joblib


joblib.dump(ensemble_model, "mri_ensemble_model.pkl")
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']
