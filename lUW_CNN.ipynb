# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout,
                                     Conv2DTranspose, Concatenate, UpSampling2D, GlobalAveragePooling2D)
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt


dataset_dir = "C:\\Users\\Lenovo\\.cache\\kagglehub\\datasets\\uzairkhan45\\breast-cancer-patients-mris\\versions\\1\\Breast Cancer Patients MRI's\\train"
img_size = (128, 128)
batch_size = 32


datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    validation_split=0.2, 
    rotation_range=15,
    zoom_range=0.1,
    horizontal_flip=True
)


train_generator_cnn = datagen.flow_from_directory(
    dataset_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)

train_generator_unet = datagen.flow_from_directory(
    dataset_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)

val_generator = datagen.flow_from_directory(
    dataset_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'
)


def build_cnn_model():
    model = tf.keras.Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model


def build_unet_binary_classification(input_shape=(128, 128, 3)):
    inputs = Input(input_shape)

    
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    p2 = MaxPooling2D((2, 2))(c2)

   
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)

  
    u4 = UpSampling2D((2, 2))(c3)
    c4 = Conv2D(128, (3, 3), activation='relu', padding='same')(u4)

    u5 = UpSampling2D((2, 2))(c4)
    c5 = Conv2D(64, (3, 3), activation='relu', padding='same')(u5)


    x = GlobalAveragePooling2D()(c5)  
    x = Dense(64, activation='relu')(x)
    outputs = Dense(1, activation='sigmoid')(x)

    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model


cnn_model = build_cnn_model()
unet_model = build_unet_binary_classification()


cnn_history = cnn_model.fit(train_generator_cnn, validation_data=val_generator, epochs=10)
unet_history = unet_model.fit(train_generator_unet, validation_data=val_generator, epochs=10)


cnn_model.save("cnn_model.h5")
unet_model.save("unet_model.h5")



def ensemble_model(cnn, unet):
    
    cnn_output = cnn.output


    unet_output = unet.output

   
    cnn_output_resized = Dense(64, activation='relu')(cnn_output)
    unet_output_resized = Dense(64, activation='relu')(unet_output)


    merged = tf.keras.layers.concatenate([cnn_output_resized, unet_output_resized])
    output = Dense(1, activation='sigmoid')(merged)

    ensemble_model = Model(inputs=[cnn.input, unet.input], outputs=output)
    ensemble_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return ensemble_model


ensemble = ensemble_model(cnn_model, unet_model)
ensemble.summary()

ensemble_history = ensemble.fit(
    [train_generator_cnn, train_generator_unet],
    validation_data=([val_generator, val_generator]),
    epochs=10
)


ensemble.save("ensemble_model.h5")


def evaluate_model(model, generator, title):
    loss, accuracy = model.evaluate(generator)
    print(f"{title} - Loss: {loss:.4f}, Accuracy: {accuracy:.4f}")

    y_true = generator.classes
    y_pred = (model.predict(generator) > 0.5).astype("int32")

    print(f"Confusion Matrix for {title}:")
    print(confusion_matrix(y_true, y_pred))
    print(classification_report(y_true, y_pred))


evaluate_model(cnn_model, val_generator, "CNN Model")
evaluate_model(unet_model, val_generator, "Lightweight U-Net Model")
evaluate_model(ensemble, val_generator, "Ensemble Model")


def plot_history(history, title):
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title(f'{title} Accuracy')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'{title} Loss')
    plt.legend()

    plt.show()

# Plot all models
plot_history(cnn_history, "CNN")
plot_history(unet_history, "U-Net")
plot_history(ensemble_history, "Ensemble")
# Out:
# Found 1120 images belonging to 2 classes.
# Found 1120 images belonging to 2 classes.
# Found 280 images belonging to 2 classes.
# Epoch 1/10
# 35/35 [==============================] - 18s 490ms/step - loss: 0.7281 - accuracy: 0.5125 - val_loss: 0.6861 - val_accuracy: 0.6750
# Epoch 2/10
# 35/35 [==============================] - 18s 501ms/step - loss: 0.6717 - accuracy: 0.5714 - val_loss: 0.7206 - val_accuracy: 0.6321
# Epoch 3/10
# 35/35 [==============================] - 18s 517ms/step - loss: 0.6345 - accuracy: 0.6134 - val_loss: 0.7946 - val_accuracy: 0.5500
# Epoch 4/10
# 35/35 [==============================] - 17s 494ms/step - loss: 0.6024 - accuracy: 0.6643 - val_loss: 0.8654 - val_accuracy: 0.5607
# Epoch 5/10
# 35/35 [==============================] - 17s 497ms/step - loss: 0.5634 - accuracy: 0.6795 - val_loss: 0.8952 - val_accuracy: 0.6107
# Epoch 6/10
# 35/35 [==============================] - 18s 500ms/step - loss: 0.5279 - accuracy: 0.7241 - val_loss: 1.2567 - val_accuracy: 0.4893
# Epoch 7/10
# 35/35 [==============================] - 18s 521ms/step - loss: 0.5078 - accuracy: 0.7446 - val_loss: 0.9327 - val_accuracy: 0.5750
# Epoch 8/10
# 35/35 [==============================] - 18s 500ms/step - loss: 0.4779 - accuracy: 0.7679 - val_loss: 1.2556 - val_accuracy: 0.5429
# Epoch 9/10
# 35/35 [==============================] - 19s 534ms/step - loss: 0.4556 - accuracy: 0.7875 - val_loss: 0.9168 - val_accuracy: 0.5893
# Epoch 10/10
# 35/35 [==============================] - 17s 492ms/step - loss: 0.4456 - accuracy: 0.7920 - val_loss: 0.9002 - val_accuracy: 0.6214
# Epoch 1/10
# 35/35 [==============================] - 192s 5s/step - loss: 0.6957 - accuracy: 0.5045 - val_loss: 0.6927 - val_accuracy: 0.5000
# Epoch 2/10
# 35/35 [==============================] - 193s 6s/step - loss: 0.6930 - accuracy: 0.5045 - val_loss: 0.6921 - val_accuracy: 0.5000
# Epoch 3/10
# 35/35 [==============================] - 231s 7s/step - loss: 0.6937 - accuracy: 0.4991 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 4/10
# 35/35 [==============================] - 273s 8s/step - loss: 0.6934 - accuracy: 0.4795 - val_loss: 0.6928 - val_accuracy: 0.5000
# Epoch 5/10
# 35/35 [==============================] - 244s 7s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6922 - val_accuracy: 0.5571
# Epoch 6/10
# 35/35 [==============================] - 282s 8s/step - loss: 0.6928 - accuracy: 0.5223 - val_loss: 0.6908 - val_accuracy: 0.7000
# Epoch 7/10
# 35/35 [==============================] - 250s 7s/step - loss: 0.6920 - accuracy: 0.5250 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 8/10
# 35/35 [==============================] - 258s 7s/step - loss: 0.6939 - accuracy: 0.5000 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 9/10
# 35/35 [==============================] - 275s 8s/step - loss: 0.6934 - accuracy: 0.5000 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 10/10
# 35/35 [==============================] - 251s 7s/step - loss: 0.6934 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 64  1792        ['input_4[0][0]']
#                                 )
#
#  conv2d_21_input (InputLayer)   [(None, 128, 128, 3  0           []
#                                 )]
#
#  max_pooling2d_18 (MaxPooling2D  (None, 64, 64, 64)  0           ['conv2d_24[0][0]']
#  )
#
#  conv2d_21 (Conv2D)             (None, 126, 126, 32  896         ['conv2d_21_input[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 128)  73856       ['max_pooling2d_18[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 63, 63, 32)  0           ['conv2d_21[0][0]']
#  )
#
#  max_pooling2d_19 (MaxPooling2D  (None, 32, 32, 128)  0          ['conv2d_25[0][0]']
#  )
#
#  conv2d_22 (Conv2D)             (None, 61, 61, 64)   18496       ['max_pooling2d_15[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 256)  295168      ['max_pooling2d_19[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 30, 30, 64)  0           ['conv2d_22[0][0]']
#  )
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 256)  0           ['conv2d_26[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 28, 28, 128)  73856       ['max_pooling2d_16[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 128)  295040      ['up_sampling2d[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 14, 14, 128)  0          ['conv2d_23[0][0]']
#  )
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 12  0          ['conv2d_27[0][0]']
#                                 8)
#
#  flatten_3 (Flatten)            (None, 25088)        0           ['max_pooling2d_17[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 128, 128, 64  73792       ['up_sampling2d_1[0][0]']
#                                 )
#
#  dense_6 (Dense)                (None, 128)          3211392     ['flatten_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['conv2d_28[0][0]']
#  alAveragePooling2D)
#
#  dropout_3 (Dropout)            (None, 128)          0           ['dense_6[0][0]']
#
#  dense_8 (Dense)                (None, 64)           4160        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_7 (Dense)                (None, 1)            129         ['dropout_3[0][0]']
#
#  dense_9 (Dense)                (None, 1)            65          ['dense_8[0][0]']
#
#  dense_10 (Dense)               (None, 64)           128         ['dense_7[0][0]']
#
#  dense_11 (Dense)               (None, 64)           128         ['dense_9[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 128)          0           ['dense_10[0][0]',
#                                                                   'dense_11[0][0]']
#
#  dense_12 (Dense)               (None, 1)            129         ['concatenate_6[0][0]']
#
# ==================================================================================================
# Total params: 4,049,027
# Trainable params: 4,049,027
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 147
#     144 ensemble.summary()
#     146 # Training ensemble
# --> 147 ensemble_history = ensemble.fit(
#     148     [train_generator_cnn, train_generator_unet],
#     149     validation_data=([val_generator, val_generator]),
#     150     epochs=10
#     151 )
#     153 # Save the ensemble model
#     154 ensemble.save("ensemble_model.h5")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:1081, in select_data_adapter(x, y)
#    1078 adapter_cls = [cls for cls in ALL_ADAPTER_CLS if cls.can_handle(x, y)]
#    1079 if not adapter_cls:
#    1080     # TODO(scottzhu): This should be a less implementation-specific error.
# -> 1081     raise ValueError(
#    1082         "Failed to find data adapter that can handle input: {}, {}".format(
#    1083             _type_name(x), _type_name(y)
#    1084         )
#    1085     )
#    1086 elif len(adapter_cls) > 1:
#    1087     raise RuntimeError(
#    1088         "Data adapters should be mutually exclusive for "
#    1089         "handling inputs. Found multiple adapters {} to handle "
#    1090         "input: {}, {}".format(adapter_cls, _type_name(x), _type_name(y))
#    1091     )
#
# ValueError: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {"<class 'keras.preprocessing.image.DirectoryIterator'>"}), <class 'NoneType'>

# %%
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 64  1792        ['input_4[0][0]']
#                                 )
#
#  conv2d_21_input (InputLayer)   [(None, 128, 128, 3  0           []
#                                 )]
#
#  max_pooling2d_18 (MaxPooling2D  (None, 64, 64, 64)  0           ['conv2d_24[0][0]']
#  )
#
#  conv2d_21 (Conv2D)             (None, 126, 126, 32  896         ['conv2d_21_input[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 128)  73856       ['max_pooling2d_18[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 63, 63, 32)  0           ['conv2d_21[0][0]']
#  )
#
#  max_pooling2d_19 (MaxPooling2D  (None, 32, 32, 128)  0          ['conv2d_25[0][0]']
#  )
#
#  conv2d_22 (Conv2D)             (None, 61, 61, 64)   18496       ['max_pooling2d_15[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 256)  295168      ['max_pooling2d_19[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 30, 30, 64)  0           ['conv2d_22[0][0]']
#  )
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 256)  0           ['conv2d_26[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 28, 28, 128)  73856       ['max_pooling2d_16[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 128)  295040      ['up_sampling2d[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 14, 14, 128)  0          ['conv2d_23[0][0]']
#  )
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 12  0          ['conv2d_27[0][0]']
#                                 8)
#
#  flatten_3 (Flatten)            (None, 25088)        0           ['max_pooling2d_17[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 128, 128, 64  73792       ['up_sampling2d_1[0][0]']
#                                 )
#
#  dense_6 (Dense)                (None, 128)          3211392     ['flatten_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['conv2d_28[0][0]']
#  alAveragePooling2D)
#
#  dropout_3 (Dropout)            (None, 128)          0           ['dense_6[0][0]']
#
#  dense_8 (Dense)                (None, 64)           4160        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_7 (Dense)                (None, 1)            129         ['dropout_3[0][0]']
#
#  dense_9 (Dense)                (None, 1)            65          ['dense_8[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 2)            0           ['dense_7[0][0]',
#                                                                   'dense_9[0][0]']
#
#  dense_14 (Dense)               (None, 1)            3           ['concatenate_8[0][0]']
#
# ==================================================================================================
# Total params: 4,048,645
# Trainable params: 4,048,645
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/10
# 35/35 [==============================] - 271s 8s/step - loss: 0.7155 - accuracy: 0.4536 - val_loss: 0.6970 - val_accuracy: 0.5000
# Epoch 2/10
# 35/35 [==============================] - 301s 9s/step - loss: 0.6940 - accuracy: 0.5027 - val_loss: 0.6934 - val_accuracy: 0.4536
# Epoch 3/10
# 35/35 [==============================] - 230s 7s/step - loss: 0.6905 - accuracy: 0.5259 - val_loss: 0.6887 - val_accuracy: 0.6500
# Epoch 4/10
# 35/35 [==============================] - 160s 5s/step - loss: 0.6842 - accuracy: 0.5411 - val_loss: 0.6739 - val_accuracy: 0.6571
# Epoch 5/10
# 35/35 [==============================] - 159s 5s/step - loss: 0.6731 - accuracy: 0.5768 - val_loss: 0.6676 - val_accuracy: 0.6071
# Epoch 6/10
# 35/35 [==============================] - 158s 5s/step - loss: 0.6419 - accuracy: 0.6661 - val_loss: 0.6650 - val_accuracy: 0.6107
# Epoch 7/10
# 35/35 [==============================] - 160s 5s/step - loss: 0.6335 - accuracy: 0.6866 - val_loss: 0.6567 - val_accuracy: 0.6393
# Epoch 8/10
# 35/35 [==============================] - 163s 5s/step - loss: 0.6346 - accuracy: 0.6705 - val_loss: 0.7009 - val_accuracy: 0.5107
# Epoch 9/10
# 35/35 [==============================] - 159s 5s/step - loss: 0.6235 - accuracy: 0.6938 - val_loss: 0.6789 - val_accuracy: 0.5857
# Epoch 10/10
# 35/35 [==============================] - 159s 5s/step - loss: 0.6104 - accuracy: 0.7250 - val_loss: 0.6732 - val_accuracy: 0.5750
# Ensemble model trained and saved successfully.

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix


y_true = []
y_pred = []


for i in range(len(val_ensemble_generator)):
    (X_cnn, X_unet), y_batch = val_ensemble_generator[i]
    
    
    preds = ensemble.predict([X_cnn, X_unet])
   
    preds_binary = (preds > 0.5).astype(int)
    
    y_true.extend(y_batch)
    y_pred.extend(preds_binary)


y_true = np.array(y_true)
y_pred = np.array(y_pred)


print("\n📊 Classification Report:")
print(classification_report(y_true, y_pred))


print("\n🔍 Confusion Matrix:")
print(confusion_matrix(y_true, y_pred))


loss, accuracy = ensemble.evaluate(val_ensemble_generator)
print(f"\n✅ Model Evaluation:\nLoss: {loss:.4f}\nAccuracy: {accuracy:.4f}")
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 963ms/step
# 1/1 [==============================] - 1s 918ms/step
# 1/1 [==============================] - 1s 925ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 914ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 970ms/step
# 1/1 [==============================] - 1s 796ms/step
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.79      0.65       140
#          1.0       0.64      0.39      0.48       140
#
#     accuracy                           0.59       280
#    macro avg       0.60      0.59      0.57       280
# weighted avg       0.60      0.59      0.57       280
#
#
# 🔍 Confusion Matrix:
# [[110  30]
#  [ 86  54]]
# 9/9 [==============================] - 9s 1s/step - loss: 0.6789 - accuracy: 0.5714
#
# ✅ Model Evaluation:
# Loss: 0.6789
# Accuracy: 0.5714
